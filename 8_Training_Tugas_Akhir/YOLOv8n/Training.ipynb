# %%
import yaml
from ultralytics import YOLO
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'

# 1. Create the dataset.yaml file required by YOLO
yaml_content = {
    'path': os.path.abspath('../Images/YOLO_Dataset'),
    'train': 'images/train',
    'val': 'images/val',
    'test': 'images/test',
    'names': {
        0: '1-ball',
        1: '2-ball',
        2: '3-ball',
        3: '4-ball',
        4: '5-ball',
        5: '6-ball',
        6: '7-ball',
        7: '8-ball',
        8: '9-ball',
        9: 'cue',
        10: 'cue_stick',
        11: 'pocket',
        12: 'rack'
    }
}

with open('dataset.yaml', 'w') as f:
    yaml.dump(yaml_content, f, sort_keys=False)

print("dataset.yaml created successfully.")

# 2. Download YOLOv8n and Train
model = YOLO('yolov8n.pt') 

print("Starting training...")
results = model.train(
    data='dataset.yaml',
    epochs=100,
    imgsz=640,
    batch=8,
    patience=10,
    workers=4,
    close_mosaic=20,
    cos_lr=True,
    project=os.path.abspath('../Trained_Models'), 
    name='ImageFixYOLOv8n'
)
# Out:
# dataset.yaml created successfully.
# Starting training...
# New https://pypi.org/project/ultralytics/8.4.65 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.115  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=dataset.yaml, epochs=100, time=None, patience=10, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=4, project=c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models, name=ImageFixYOLOv8n, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=20, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models\ImageFixYOLOv8n
# Overriding model.yaml nc=80 with nc=13
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753847  ultralytics.nn.modules.head.Detect           [13, [64, 128, 256]]
# Model summary: 129 layers, 3,013,383 parameters, 3,013,367 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# WARNING ClearML installed but not initialized correctly, not logging this run. It seems ClearML is not configured on this machine!
# To get started with ClearML, setup your own 'clearml-server' or create a free account at https://app.clear.ml
# Setup instructions can be found here: https://clear.ml/docs
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 321.7275.3 MB/s, size: 1089.3 KB)
# train: Scanning C:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Images\YOLO_Dataset\labels\train.cache... 2976 images, 8 backgrounds, 0 corrupt: 100%|██████████| 2976/2976 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.20.0 ms, read: 464.6279.9 MB/s, size: 512.2 KB)
# val: Scanning C:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Images\YOLO_Dataset\labels\val.cache... 212 images, 0 backgrounds, 0 corrupt: 100%|██████████| 212/212 [00:00<?, ?it/s]
# Plotting labels to c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models\ImageFixYOLOv8n\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000588, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# 2026/06/11 20:05:37 WARNING mlflow.utils.autologging_utils: MLflow statsmodels autologging is known to be compatible with 0.14.3 <= statsmodels, but the installed version is 0.14.2. If you encounter errors during autologging, try upgrading / downgrading statsmodels to a compatible version, or try upgrading MLflow.
# 2026/06/11 20:05:37 INFO mlflow.tracking.fluent: Autologging successfully enabled for statsmodels.
# MLflow: logging run_id(3eb7567725a9488584ad5c6d934ebfc3) to runs\mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs\mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models\ImageFixYOLOv8n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      1.27G      1.536      2.283     0.9703        160        640: 100%|██████████| 372/372 [00:39<00:00,  9.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.73it/s]
#                    all        212       2899       0.55      0.604      0.533      0.336
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      1.34G      1.273      1.042     0.9133        172        640: 100%|██████████| 372/372 [00:39<00:00,  9.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.86it/s]
#                    all        212       2899      0.909      0.779      0.849      0.573
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      1.34G      1.204     0.8474     0.8992        217        640: 100%|██████████| 372/372 [00:41<00:00,  9.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  8.19it/s]
#                    all        212       2899      0.946      0.817      0.885      0.611
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      1.34G      1.148      0.761     0.8913        226        640: 100%|██████████| 372/372 [00:42<00:00,  8.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.72it/s]
#                    all        212       2899      0.947      0.828      0.895      0.598
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      1.34G      1.128     0.7018     0.8897        193        640: 100%|██████████| 372/372 [00:41<00:00,  9.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.74it/s]
#                    all        212       2899      0.879      0.869       0.91      0.633
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      1.34G        1.1     0.6696      0.887        157        640: 100%|██████████| 372/372 [00:43<00:00,  8.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.60it/s]
#                    all        212       2899      0.916      0.879      0.916      0.629
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      1.34G      1.109     0.6475     0.8841        153        640: 100%|██████████| 372/372 [00:42<00:00,  8.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.22it/s]
#                    all        212       2899      0.917      0.865      0.911      0.635
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      1.34G      1.091     0.6225     0.8828        189        640: 100%|██████████| 372/372 [00:43<00:00,  8.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:01<00:00,  7.19it/s]
#                    all        212       2899      0.894      0.864       0.91      0.627
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      1.34G      1.078     0.5999     0.8813        137        640: 100%|██████████| 372/372 [00:44<00:00,  8.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████|
13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:02<00:00,  6.88it/s]
#                    all        212       2899      0.937      0.923      0.928      0.687
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      1.34G     0.8821     0.4106     0.8451        178        640: 100%|██████████| 372/372 [00:45<00:00,  8.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:02<00:00,  6.79it/s]
#                    all        212       2899       0.94      0.914      0.926      0.686
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 43, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 53 epochs completed in 0.697 hours.
# Optimizer stripped from c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models\ImageFixYOLOv8n\weights\last.pt, 6.2MB
# Optimizer stripped from c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models\ImageFixYOLOv8n\weights\best.pt, 6.2MB
#
# Validating c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models\ImageFixYOLOv8n\weights\best.pt...
# Ultralytics 8.3.115  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Model summary (fused): 72 layers, 3,008,183 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:03<00:00,  3.87it/s]
#                    all        212       2899      0.957       0.91      0.928      0.696
#                 1-ball        104        106      0.962      0.877      0.904      0.706
#                 2-ball        130        133      0.999       0.94      0.967      0.717
#                 3-ball        142        155       0.96      0.871      0.919       0.72
#                 4-ball        154        154       0.94      0.987      0.992       0.78
#                 5-ball        164        164      0.994      0.988      0.993      0.759
#                 6-ball        173        173      0.994      0.987      0.995      0.751
#                 7-ball        185        186      0.974      0.952      0.985      0.739
#                 8-ball        186        187      0.991      0.984      0.988      0.764
#                 9-ball        199        201      0.991       0.98      0.988       0.71
#                    cue        208        211      0.995      0.975      0.992      0.756
#              cue_stick         47         47      0.725      0.298      0.359      0.103
#                 pocket        198       1174      0.978      0.991      0.984       0.79
#                   rack          8          8      0.935          1      0.995      0.751
# Speed: 0.4ms preprocess, 3.0ms inference, 0.0ms loss, 3.0ms postprocess per image
# Results saved to c:\Users\Axioo Pongo\Desktop\All_in_One\College\Tugas Akhir\Pre-Processing Backup\Pre-Processing\8_Training_Tugas_Akhir\Trained_Models\ImageFixYOLOv8n
# MLflow: results logged to runs\mlflow
# MLflow: disable with 'yolo settings mlflow=False'

# %%
from ultralytics import YOLO

# 1. Load your newly trained model weights
# Update the path if your project saved it elsewhere
model = YOLO('../Trained_Models/YOLOv8n4/weights/best.pt')

# 2. Print the model architecture summary
model.info()
# Out:
# Model summary: 129 layers, 3,013,383 parameters, 0 gradients, 8.2 GFLOPs
# (129, 3013383, 0, 8.207052800000001)
